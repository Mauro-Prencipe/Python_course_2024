# %% [markdown]
# ### Importing our own classes and functions
#
# ... to  work only with data in the way we want, without being *distracted* by the code we wrote...
#
# Each class and function was written in the *einstein_fit.py* file (saved in the same folder of this notebook).

# %%
from einstein_fit import *

# %%
my_plot.set_param(tex=False, fsize=16, tsize=14, dpi=200, figsize=(8,6), save=True)
py=data_class('pyrope', 'cv_data.dat', 20)
qt=data_class('quartz', 'quartz_cv.dat', 3)

py.read('data_files')
py.info()

print("\n")
qt.read('data_files')
qt.info()
# Out:
# Data set name pyrope
# Data set file cv_data.dat
# apfu:   20
# Number of T points:   20
# Minimum and maximum temperatures:  20.0, 700.0
# Fitting model:  None
#
#
# Data set name quartz
# Data set file quartz_cv.dat
# apfu:    3
# Number of T points:   30
# Minimum and maximum temperatures:  20.0, 650.0
# Fitting model:  None

# %%
compare_fit(py)
# Out:
# Einstein temperature:   633.4 (K)
# Einstein temperatures:  1017.9, 341.5 (K)
#
#   T       Cv Exp   model 1   model 2
#  20.0       4.37      0.00      0.00
#  56.0      31.53      0.78     20.95
#  92.0      85.15     24.25     88.72
# 127.0     141.41     85.85    146.39
# 163.0     193.78    161.22    194.16
# 199.0     238.55    228.10    235.96
# 235.0     276.19    281.44    273.00
# 271.0     307.68    322.55    305.14
# 306.0     333.31    353.28    331.75
# 342.0     355.39    377.77    354.78
# 378.0     373.85    396.88    374.00
# 414.0     389.33    411.98    390.02
# 449.0     402.00    423.77    403.07
# 485.0     413.02    433.63    414.37
# 521.0     422.34    441.72    423.91
# 557.0     430.27    448.42    432.00
# 593.0     437.06    454.03    438.91
# 628.0     442.75    458.65    444.69
# 664.0     447.85    462.70    449.84
# 700.0     452.32    466.18    454.31

# %%
py.select(300)
compare_fit(py)
py.info()
# Out:
# Einstein temperature:   716.9 (K)
# Einstein temperatures:  258.9, 1066.9 (K)
#
#   T       Cv Exp   model 1   model 2
# 306.0     333.31    321.88    333.82
# 342.0     355.39    350.26    355.23
# 378.0     373.85    372.81    373.46
# 414.0     389.33    390.88    388.91
# 449.0     402.00    405.14    401.65
# 485.0     413.02    417.15    412.79
# 521.0     422.34    427.08    422.26
# 557.0     430.27    435.35    430.35
# 593.0     437.06    442.30    437.29
# 628.0     442.75    448.04    443.13
# 664.0     447.85    453.10    448.34
# 700.0     452.32    457.46    452.89
# Data set name pyrope
# Data set file cv_data.dat
# apfu:   20
# Number of T points:   20
# Original temperature range restricted to the [300.0, 700.0 K] interval
# Minimum and maximum temperatures: 306.0, 700.0
# one temperature model; Einstein temperature: 716.9 (K)
# two temperatures model; Einstein temperatures: 258.9, 1066.9 (K)

# %%
compare_fit(qt)
# Out:
# Einstein temperature:   745.1 (K)
# Einstein temperatures:  343.5, 1320.9 (K)
#
#    T       Cv Exp   model 1   model 2
#  20.00       1.40      0.00      0.00
#  41.72       4.11      0.00      0.67
#  63.45       7.67      0.08      4.93
#  85.17      11.66      0.91     11.18
# 106.90      15.82      3.42     16.90
# 128.62      19.92      7.70     21.46
# 150.34      23.84     13.12     25.09
# 172.07      27.49     18.97     28.15
# 193.79      30.84     24.70     30.90
# 215.52      33.89     30.05     33.49
# 237.24      36.65     34.87     35.98
# 258.97      39.15     39.15     38.39
# 280.69      41.43     42.91     40.71
# 302.41      43.52     46.18     42.92
# 324.14      45.45     49.05     45.03
# 345.86      47.24     51.54     47.01
# 367.59      48.93     53.72     48.86
# 389.31      50.53     55.63     50.58
# 411.03      52.04     57.31     52.18
# 432.76      53.48     58.79     53.66
# 454.48      54.83     60.10     55.02
# ...

# %%
qt.select(300)
compare_fit(qt)
qt.info()
# Out:
# Einstein temperature:   862.9 (K)
# Einstein temperatures:  263.5, 1371.9 (K)
#
#    T       Cv Exp   model 1   model 2
# 302.41      43.52     39.55     43.56
# 324.14      45.45     42.78     45.44
# 345.86      47.24     45.65     47.24
# 367.59      48.93     48.20     48.95
# 389.31      50.53     50.47     50.56
# 411.03      52.04     52.49     52.07
# 432.76      53.48     54.28     53.49
# 454.48      54.83     55.89     54.80
# 476.21      56.11     57.32     56.02
# 497.93      57.28     58.61     57.15
# 519.66      58.36     59.77     58.20
# 541.38      59.34     60.81     59.17
# 563.10      60.20     61.76     60.07
# 584.83      60.95     62.61     60.90
# 606.55      61.60     63.39     61.68
# 628.28      62.15     64.10     62.39
# 650.00      62.63     64.74     63.05
# Data set name quartz
# Data set file quartz_cv.dat
# apfu:    3
# Number of T points:   30
# Original temperature range restricted to the [300.0, 650.0 K] interval
# ...
